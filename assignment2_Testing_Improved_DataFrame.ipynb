# %% [markdown]
# <a href="https://colab.research.google.com/github/Tclack88/DS-Unit-3-Sprint-1-Software-Engineering/blob/master/assignment2_Testing_Improved_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -i https://test.pypi.org/simple/ lambdata-tclack==0.1.4
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...

# %%
import pandas as pd

# examply of a messy dataframe, look at those columns, gross!!
url = "https://raw.githubusercontent.com/realpython/python-data-cleaning/master/Datasets/BL-Flickr-Images-Book.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    Identifier  ...                           Shelfmarks
# 0         206  ...    British Library HMNTS 12641.b.30.
# 1         216  ...    British Library HMNTS 12626.cc.2.
# 2         218  ...    British Library HMNTS 12625.dd.1.
# 3         472  ...  British Library HMNTS 10369.bbb.15.
# 4         480  ...     British Library HMNTS 9007.d.28.
#
# [5 rows x 15 columns]

# %%
from lambdata_tclack.df_utils import ImprovedDataFrame

# %%
type(df)  # check the original type is a pandas dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
df = ImprovedDataFrame(df)  # convert to animiproved dataframe

# %%
type(df)  # check the new type is an "improved dataframe"
# Out:
# lambdata_tclack.df_utils.ImprovedDataFrame

# %% [markdown]
# ### Run my new methods

# %%
df.simplify_cols()
# Out:
#       identifier  ...                                         shelfmarks
# 0            206  ...                  British Library HMNTS 12641.b.30.
# 1            216  ...                  British Library HMNTS 12626.cc.2.
# 2            218  ...                  British Library HMNTS 12625.dd.1.
# 3            472  ...                British Library HMNTS 10369.bbb.15.
# 4            480  ...                   British Library HMNTS 9007.d.28.
# ...          ...  ...                                                ...
# 8282     4158088  ...  British Library HMNTS|British Library HMNTS 10...
# 8283     4158128  ...  British Library HMNTS|British Library HMNTS 10...
# 8284     4159563  ...  British Library HMNTS|British Library HMNTS 19...
# 8285     4159587  ...  British Library HMNTS|British Library HMNTS 10...
# 8286     4160339  ...  British Library HMNTS|British Library HMNTS 79...
#
# [8287 rows x 15 columns]

# %%
df.correctify()
# Out:
#           Identifier Edition Statement  ...      Flickr URL      Shelfmarks
# 0     Mikayla Smells    Mikayla Smells  ...  Mikayla Smells  Mikayla Smells
# 1     Mikayla Smells    Mikayla Smells  ...  Mikayla Smells  Mikayla Smells
# 2     Mikayla Smells    Mikayla Smells  ...  Mikayla Smells  Mikayla Smells
# 3     Mikayla Smells    Mikayla Smells  ...  Mikayla Smells  Mikayla Smells
# 4     Mikayla Smells    Mikayla Smells  ...  Mikayla Smells  Mikayla Smells
# ...              ...               ...  ...             ...             ...
# 8282  Mikayla Smells    Mikayla Smells  ...  Mikayla Smells  Mikayla Smells
# 8283  Mikayla Smells    Mikayla Smells  ...  Mikayla Smells  Mikayla Smells
# 8284  Mikayla Smells    Mikayla Smells  ...  Mikayla Smells  Mikayla Smells
# 8285  Mikayla Smells    Mikayla Smells  ...  Mikayla Smells  Mikayla Smells
# 8286  Mikayla Smells    Mikayla Smells  ...  Mikayla Smells  Mikayla Smells
#
# [8287 rows x 15 columns]

# %% [markdown]
# # :]
